# %% [markdown]
# <a href="https://colab.research.google.com/github/imanuni/imanuni/blob/main/try2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BeautifulSoup4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests



url=f"http://www.pcm.gov.lb/arabic/listingbydate.aspx?pageid=16"
result=requests.get(url)
doc = BeautifulSoup(result.text,"html.parser")
gpu_containers = doc.find_all('ul',class_="ctl00_maincont_ulList")

for title_tag in gpu_containers:
  try:
    print(title_tag.find('li',class_="ctl00_maincont_rpArticles_ctl02_liItem").string)
  except:
    continue

# %%
from bs4 import BeautifulSoup
import requests



url="http://www.pcm.gov.lb/arabic/listingbydate.aspx?pageid=16"
while url:
  response = requests.get(url)
  soup = BeautifulSoup(response.text,'html.parser')

paragraphs = soup.find_all('div', class_="summaryNewsContainer")
for paragraph in paragraphs:
        text = paragraph.text.strip()
        print(text)

        pagination = soup.find_all('a', class_="paging")  # Vous pouvez ajuster la classe selon le HTML
        next_page = None
        current_page = int(url.split('=')[-1])  # On extrait le numéro de la page actuelle de l'URL

# Recherche du lien de la page suivante (numéro suivant)
for page_link in pagination:
        try:
            page_number = int("javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;ctl00$maincont$dlPages$ctl00$lbtnPage&quot;, &quot;&quot;, true, &quot;&quot;, &quot;&quot;, false, true".text.strip())  # On extrait le numéro de la page
            if page_number == current_page + 1:
                next_page = page_link.get('href=""javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;ctl00$maincont$dlPages$ctl02$lbtnPage&quot;, &quot;&quot;, true, &quot;&quot;, &quot;&quot;, false, true))"')  # On récupère l'URL de la page suivante
                break
        except ValueError:
            # Si ce n'est pas un numéro de page (par exemple, "Suivant" ou autre), ignorer
            continue

    # Si un lien vers la page suivante est trouvé, mettre à jour l'URL, sinon arrêter la boucle
if next_page:
        url = "http://www.pcm.gov.lb/arabic/" + next_page
else:
        url = None
     # if next_page:
         # url = next_page.get('http://www.pcm.gov.lb/arabic/listingbydate.aspx?pageid=16')  # L'URL de la page suivante
          #paragraphs = soup.find_all('div', class_="summaryNewsContainer")
          #for paragraph in paragraphs:
           # text = paragraph.text.strip()
            #print(text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b687362c6b47> in <cell line: 7>()
#       6 url="http://www.pcm.gov.lb/arabic/listingbydate.aspx?pageid=16"
#       7 while url:
# ----> 8   response = requests.get(url)
#       9   soup = BeautifulSoup(response.text,'html.parser')
#      10
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...
